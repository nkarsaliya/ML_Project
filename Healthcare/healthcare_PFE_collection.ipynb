# %%
import requests
import pandas as pd
from pandas import json_normalize
import csv
import time

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
def get_data(year,month):
    ticker="PFE"
    
    f=open("alpha access key.txt", "r");
    apikey=f.read()
    
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol='+ticker+'&interval=1min&slice=year'+str(year)+'month'+str(month)+'&apikey='+apikey
   

    with requests.Session() as s:
        download = s.get(url)
        decoded_content = download.content.decode('utf-8')
        cr = csv.reader(decoded_content.splitlines(), delimiter=',')
        my_list = list(cr)
    return my_list

# %%
def create_df(my_list):
    df_data=pd.DataFrame(my_list[1:])
    df_data.columns=my_list[0]
    return df_data

# %%
df_final=pd.DataFrame(columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
for i in range(1,3):
    for j in range (1,13):
        my_list=get_data(i,j)
        print(i,j)
        print('downloaded data')
        df_data=create_df(my_list)
        print(i,j)
        print('dataframe created')
        df_final=df_final.append(df_data,ignore_index=True)
        
      
        time.sleep(20)
df_final = df_final.drop(columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
# Out:
# 1 1
# downloaded data
# 1 1
# dataframe created
# 1 2
# downloaded data
# 1 2
# dataframe created
# 1 3
# downloaded data
# 1 3
# dataframe created
# 1 4
# downloaded data
# 1 4
# dataframe created
# 1 5
# downloaded data
# 1 5
# dataframe created
# 1 6
# downloaded data
# 1 6
# dataframe created
# 1 7
# downloaded data
# 1 7
# dataframe created
# 1 8
# downloaded data
# 1 8
# dataframe created
# 1 9
# downloaded data
# 1 9
# dataframe created
# 1 10
# downloaded data
# 1 10
# dataframe created
# 1 11
# downloaded data
# 1 11
# dataframe created
# 1 12
# downloaded data
# 1 12
# dataframe created
# 2 1
# downloaded data
# 2 1
# dataframe created
# 2 2
# downloaded data
# 2 2
# dataframe created
# 2 3
# downloaded data
# 2 3
# dataframe created
# 2 4
# downloaded data
# 2 4
# dataframe created
# 2 5
# downloaded data
# 2 5
# dataframe created
# 2 6
# downloaded data
# 2 6
# dataframe created
# 2 7
# downloaded data
# 2 7
# dataframe created
# 2 8
# downloaded data
# 2 8
# dataframe created
# 2 9
# downloaded data
# 2 9
# dataframe created
# 2 10
# downloaded data
# 2 10
# dataframe created
# 2 11
# downloaded data
# 2 11
# dataframe created
# 2 12
# downloaded data
# 2 12
# dataframe created

# %%
df_final
# Out:
#                        time           open           high            low  \
# 0       2022-03-21 19:58:00          53.98          53.98          53.98
# 1       2022-03-21 19:57:00           54.0           54.0           54.0
# 2       2022-03-21 19:56:00          54.05          54.05          54.05
# 3       2022-03-21 19:53:00           54.0           54.0           54.0
# 4       2022-03-21 19:46:00          54.01          54.01          54.01
# ...                     ...            ...            ...            ...
# 300438  2020-04-01 07:10:00  28.0808428258  28.0808428258  28.0808428258
# 300439  2020-04-01 07:07:00  28.1159988106  28.1159988106  28.1159988106
# 300440  2020-04-01 07:03:00  28.2126777687  28.2126777687  28.1247878068
# 300441  2020-04-01 07:02:00  28.2126777687  28.2126777687  28.2126777687
# 300442  2020-04-01 07:01:00  28.3093567267  28.3093567267  28.3093567267
#
#                 close volume
# 0               53.98    228
# 1                54.0    785
# 2               54.05    250
# 3                54.0    555
# 4               54.01    369
# ...               ...    ...
# 300438  28.0808428258    222
# 300439  28.1159988106    527
# 300440  28.1247878068   3040
# 300441  28.2126777687    212
# 300442  28.3093567267    323
#
# [300443 rows x 6 columns]

# %%
df_final = df_final.drop(columns = ['volume'])

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300443 entries, 0 to 300442
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    300443 non-null  object
#  1   open    300443 non-null  object
#  2   high    300443 non-null  object
#  3   low     300443 non-null  object
#  4   close   300443 non-null  object
# dtypes: object(5)
# memory usage: 11.5+ MB

# %%
df_final[['open', 'high', 'low', 'close']] = df_final[['open', 'high', 'low', 'close']].apply(pd.to_numeric)
df_final['time']= pd.to_datetime(df_final['time'])
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300443 entries, 0 to 300442
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    300443 non-null  datetime64[ns]
#  1   open    300443 non-null  float64
#  2   high    300443 non-null  float64
#  3   low     300443 non-null  float64
#  4   close   300443 non-null  float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 11.5 MB

# %%
pd.options.mode.chained_assignment = None 
df_final['open'] = df_final['open'].astype(float).round(2)
df_final['high'] = df_final['high'].astype(float).round(2)
df_final['low'] = df_final['low'].astype(float).round(2)
df_final['close'] = df_final['close'].astype(float).round(2)

# %%
df_final.info()
df_final.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300443 entries, 0 to 300442
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    300443 non-null  datetime64[ns]
#  1   open    300443 non-null  float64
#  2   high    300443 non-null  float64
#  3   low     300443 non-null  float64
#  4   close   300443 non-null  float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 11.5 MB
#                       time   open   high    low  close
# 300438 2020-04-01 07:10:00  28.08  28.08  28.08  28.08
# 300439 2020-04-01 07:07:00  28.12  28.12  28.12  28.12
# 300440 2020-04-01 07:03:00  28.21  28.21  28.12  28.12
# 300441 2020-04-01 07:02:00  28.21  28.21  28.21  28.21
# 300442 2020-04-01 07:01:00  28.31  28.31  28.31  28.31

# %%
df_final['time'] = pd.to_datetime(df_final['time'])
df_final['Time'], df_final['Date']= df_final['time'].apply(lambda x:x.time()), df_final['time'].apply(lambda x:x.date())

# %%
clean_df = df_final[['Date', 'Time', 'open', 'high', 'low', 'close']]
clean_df = clean_df.rename(columns = {'open': 'Open', 'high': 'High', 'low': 'Low', 'close': 'Close'})
clean_df
# Out:
#               Date      Time   Open   High    Low  Close
# 0       2022-03-21  19:58:00  53.98  53.98  53.98  53.98
# 1       2022-03-21  19:57:00  54.00  54.00  54.00  54.00
# 2       2022-03-21  19:56:00  54.05  54.05  54.05  54.05
# 3       2022-03-21  19:53:00  54.00  54.00  54.00  54.00
# 4       2022-03-21  19:46:00  54.01  54.01  54.01  54.01
# ...            ...       ...    ...    ...    ...    ...
# 300438  2020-04-01  07:10:00  28.08  28.08  28.08  28.08
# 300439  2020-04-01  07:07:00  28.12  28.12  28.12  28.12
# 300440  2020-04-01  07:03:00  28.21  28.21  28.12  28.12
# 300441  2020-04-01  07:02:00  28.21  28.21  28.21  28.21
# 300442  2020-04-01  07:01:00  28.31  28.31  28.31  28.31
#
# [300443 rows x 6 columns]

# %%
clean_df.tail()
# Out:
#               Date      Time   Open   High    Low  Close
# 300438  2020-04-01  07:10:00  28.08  28.08  28.08  28.08
# 300439  2020-04-01  07:07:00  28.12  28.12  28.12  28.12
# 300440  2020-04-01  07:03:00  28.21  28.21  28.12  28.12
# 300441  2020-04-01  07:02:00  28.21  28.21  28.21  28.21
# 300442  2020-04-01  07:01:00  28.31  28.31  28.31  28.31

# %%
clean_df.to_csv('HC_PFE.csv', index=False)

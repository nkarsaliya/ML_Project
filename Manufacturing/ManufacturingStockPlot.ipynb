# %%
# importing Libraries  
# import pandas as pd
import pandas as pd
  
# importing matplotlib module
import matplotlib.pyplot as plt
plt.style.use('default')
  
# %matplotlib inline: only draw static
# images in the notebook
# %matplotlib inline

# %%
# code
# importing Data
Apple = pd.read_csv('Apple.csv',
                    index_col='Date', 
                    parse_dates=True)
Apple.head(10)
# Out:
#                 Time    Open    High     Low   Close
# Date
# 2022-03-22  20:00:00  168.90  168.95  168.90  168.95
# 2022-03-22  19:59:00  168.95  168.95  168.92  168.92
# 2022-03-22  19:58:00  168.94  168.95  168.93  168.95
# 2022-03-22  19:57:00  168.94  168.95  168.94  168.94
# 2022-03-22  19:56:00  168.95  168.95  168.93  168.93
# 2022-03-22  19:55:00  168.93  168.94  168.93  168.93
# 2022-03-22  19:53:00  168.91  168.94  168.90  168.94
# 2022-03-22  19:52:00  168.94  168.94  168.93  168.93
# 2022-03-22  19:51:00  168.94  168.94  168.93  168.93
# 2022-03-22  19:50:00  168.93  168.93  168.93  168.93

# %%
# code
# importing data
Intel = pd.read_csv('Intel.csv',
                   index_col='Date', 
                   parse_dates=True)
Intel.head(10)
# Out:
#                 Time   Open   High    Low  Close
# Date
# 2022-03-22  19:53:00  48.45  48.45  48.45  48.45
# 2022-03-22  19:52:00  48.43  48.43  48.43  48.43
# 2022-03-22  19:33:00  48.36  48.36  48.36  48.36
# 2022-03-22  19:26:00  48.34  48.34  48.34  48.34
# 2022-03-22  19:22:00  48.33  48.33  48.33  48.33
# 2022-03-22  19:12:00  48.44  48.44  48.44  48.44
# 2022-03-22  19:03:00  48.40  48.44  48.40  48.44
# 2022-03-22  18:46:00  48.36  48.36  48.36  48.36
# 2022-03-22  18:45:00  48.36  48.36  48.36  48.36
# 2022-03-22  18:43:00  48.41  48.44  48.41  48.44

# %%
# code
# importing data
GM = pd.read_csv('GeneralMotor.csv',
                 index_col='Date',
                 parse_dates=True)
# printing 10 entries of the data
GM.head(10)
# Out:
#                 Time   Open   High    Low  Close
# Date
# 2022-03-22  19:56:00  44.59  44.59  44.59  44.59
# 2022-03-22  19:48:00  44.59  44.59  44.59  44.59
# 2022-03-22  19:45:00  44.59  44.59  44.59  44.59
# 2022-03-22  19:43:00  44.58  44.58  44.58  44.58
# 2022-03-22  19:29:00  44.58  44.58  44.58  44.58
# 2022-03-22  19:27:00  44.60  44.60  44.60  44.60
# 2022-03-22  19:26:00  44.56  44.56  44.56  44.56
# 2022-03-22  19:10:00  44.56  44.56  44.56  44.56
# 2022-03-22  18:58:00  44.58  44.58  44.58  44.58
# 2022-03-22  18:54:00  44.58  44.58  44.58  44.58

# %%
# code
# importing data
TM = pd.read_csv('ToyotaMotor.csv',
                 index_col='Date',
                 parse_dates=True)
# printing 10 entries of the data
TM.head(10)
# Out:
#                 Time    Open    High     Low   Close
# Date
# 2022-03-22  16:00:00  172.83  172.90  172.73  172.74
# 2022-03-22  15:59:00  172.74  172.89  172.74  172.89
# 2022-03-22  15:58:00  172.84  172.84  172.76  172.79
# 2022-03-22  15:57:00  172.94  172.94  172.76  172.87
# 2022-03-22  15:56:00  172.97  173.00  172.90  173.00
# 2022-03-22  15:55:00  173.18  173.20  173.03  173.03
# 2022-03-22  15:54:00  173.22  173.22  173.11  173.11
# 2022-03-22  15:53:00  173.15  173.20  173.15  173.20
# 2022-03-22  15:52:00  173.18  173.22  173.18  173.22
# 2022-03-22  15:51:00  173.34  173.34  173.26  173.26

# %%
# code
# Visualizing The Open Price of all the stocks
  
# to set the plot size
sns.set(rc={"figure.figsize":(20,12)})
  
# using plot method to plot open prices.
# in plot method we set the label and color of the curve.
Apple['Close'].plot(label='Apple', color='orange')
GM['Close'].plot(label='GM',color='green')
TM['Close'].plot(label='Toyota',color='blue')
Intel['Close'].plot(label='Intel',color='red')
  
# adding title to the plot
plt.title('Manufacturing Industry Stock Price fluctuation from 2020-22',fontsize=20)
  
# adding Label to the x-axis
plt.xlabel('Date',fontsize=20)
plt.ylabel('Stock Prices (Close)',fontsize=20)
  
# adding legend to the curve
plt.legend(prop={'size': 20})
